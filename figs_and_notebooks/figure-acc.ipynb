# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# Out:
# c:\Users\natki\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# c:\Users\natki\anaconda3\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# c:\Users\natki\anaconda3\lib\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
model_performances = pd.read_excel(r'./model-key-acc.xlsx')

# %%
model_performances
# Out:
#    299-AN  Raw-EfficientNet-B3  Pre-Trained-EfficientNet-B3  Raw-VGG-16  \
# 0  72.297               73.649                       27.027      41.216
# 1  70.270               73.649                       26.351      41.216
# 2  77.027               75.676                       27.027      41.216
# 3  70.270               71.622                       30.405      41.216
# 4  75.000               66.216                       29.054      41.216
# 5  66.892               71.622                       25.000      72.973
# 6  72.973               68.919                       31.081      41.216
# 7  69.595               74.324                       22.973      41.216
# 8  69.595               72.297                       31.757      41.216
# 9  72.297               70.270                       30.405      41.216
#
#    Pre-Trained-VGG-16  Raw-ResNet-50  Pre-Trained-ResNet-50  Raw-ViT-L-16  \
# 0              43.243         70.270                 59.459        43.919
# ...

# %%
model_performances['299-AN'] = [x / 100 for x in model_performances['299-AN']]
model_performances['Raw-EfficientNet-B3'] = [x / 100 for x in model_performances['Raw-EfficientNet-B3']]
model_performances['Pre-Trained-EfficientNet-B3'] = [x / 100 for x in model_performances['Pre-Trained-EfficientNet-B3']]
model_performances['Raw-VGG-16'] = [x / 100 for x in model_performances['Raw-VGG-16']]
model_performances['Pre-Trained-VGG-16'] = [x / 100 for x in model_performances['Pre-Trained-VGG-16']]
model_performances['Raw-ResNet-50'] = [x / 100 for x in model_performances['Raw-ResNet-50']]
model_performances['Pre-Trained-ResNet-50'] = [x / 100 for x in model_performances['Pre-Trained-ResNet-50']]
model_performances['Raw-ViT-L-16'] = [x / 100 for x in model_performances['Raw-ViT-L-16']]
model_performances['Pre-Trained-ViT-L-16'] = [x / 100 for x in model_performances['Pre-Trained-ViT-L-16']]

# %%
model_performances
# Out:
#     299-AN  Raw-EfficientNet-B3  Pre-Trained-EfficientNet-B3  Raw-VGG-16  \
# 0  0.72297              0.73649                      0.27027     0.41216
# 1  0.70270              0.73649                      0.26351     0.41216
# 2  0.77027              0.75676                      0.27027     0.41216
# 3  0.70270              0.71622                      0.30405     0.41216
# 4  0.75000              0.66216                      0.29054     0.41216
# 5  0.66892              0.71622                      0.25000     0.72973
# 6  0.72973              0.68919                      0.31081     0.41216
# 7  0.69595              0.74324                      0.22973     0.41216
# 8  0.69595              0.72297                      0.31757     0.41216
# 9  0.72297              0.70270                      0.30405     0.41216
#
#    Pre-Trained-VGG-16  Raw-ResNet-50  Pre-Trained-ResNet-50  Raw-ViT-L-16  \
# 0             0.43243        0.70270                0.59459       0.43919
# ...

# %%
fig, axes = plt.subplots(figsize=(10,5))
sns.set_theme(style="ticks")
plt.xlim(0, 1)
plt.ylim(0, 1)
plt.xticks(size = 15)
plt.yticks(size = 18)
plt.xlabel("Test Accuracy", weight = 'bold', size = 18)
plt.subplots_adjust(left = 0.18)
# plt.yticks(rotation=30)
sns.violinplot(data=model_performances, ax = axes, orient ='h', scale = 'width', inner = None)
plt.scatter(x = model_performances['299-AN'], y = ['299-AN'] * 10, color = 'white', alpha = 0.3, s = 80)
plt.scatter(x = model_performances['Raw-EfficientNet-B3'], y = ['Raw-EfficientNet-B3'] * 10, color = 'white', alpha = 0.3, s = 80)
plt.scatter(x = model_performances['Pre-Trained-EfficientNet-B3'], y = ['Pre-Trained-EfficientNet-B3'] * 10, color = 'white', alpha = 0.3, s = 80)
plt.scatter(x = model_performances['Raw-VGG-16'], y = ['Raw-VGG-16'] * 10, color = 'white', alpha = 0.3, s = 80)
plt.scatter(x = model_performances['Pre-Trained-VGG-16'], y = ['Pre-Trained-VGG-16'] * 10, color = 'white', alpha = 0.3, s = 80)
plt.scatter(x = model_performances['Raw-ResNet-50'], y = ['Raw-ResNet-50'] * 10, color = 'white', alpha = 0.3, s = 80)
plt.scatter(x = model_performances['Pre-Trained-ResNet-50'], y = ['Pre-Trained-ResNet-50'] * 10, color = 'white', alpha = 0.3, s = 80)
plt.scatter(x = model_performances['Raw-ViT-L-16'], y = ['Raw-ViT-L-16'] * 10, color = 'white', alpha = 0.3, s = 80)
plt.scatter(x = model_performances['Pre-Trained-ViT-L-16'], y = ['Pre-Trained-ViT-L-16'] * 10, color = 'white', alpha = 0.3, s = 80)
# plt.violinplot(model_performances, vert = False)
plt.grid()
plt.savefig('relative-model-performances-acc.png', dpi = 1200, bbox_inches = 'tight')
